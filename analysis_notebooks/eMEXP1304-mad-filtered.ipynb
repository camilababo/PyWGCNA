# %% [markdown]
# # PyWGCNA with E-MEXP-1304
# Testing module clustering with pre-processing technique of Top 2000 most deviating genes (MAD)

# %%
import PyWGCNA
print(PyWGCNA.__file__)
# Out:
# /home/ribei027/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/PyWGCNA/__init__.py

# %% [markdown]
# ## Setting up the data and preprocessing
# Starting with the transposed dataset related to the top 2000 most deviating genes calculated by MAD

# %%
geneExp = "../data/E-MEXP-1304/e-mexp-1304-filtered-transposed.csv"
PyWGCNA_1304 = PyWGCNA.WGCNA(name='E-MEXP-1304-TPM5',
                                  species='arabidopsis thaliana',
                                  geneExpPath=geneExp,
                                  outputPath='/home/ribei027/wgcna/analysis_notebooks/',
                                  save=True,
                             TPMcutoff=1)
PyWGCNA_1304.geneExpr.to_df().head(5)
# Out:
# Saving data to be True, checking requirements ...
#              AT1G71030  AT5G45820  AT4G27450  AT1G01060  AT1G56300  AT3G47340  \
# Scan REF
# col_0_LLHC    3.308885   3.028569   4.111031  10.416481   2.608809   3.837943
# col_4_LLHC    8.398744   8.161485   9.875335   9.979754   2.733354   9.126188
# col_8_LLHC   10.663469   9.631595   9.720193   6.615004   8.264630  11.404588
# col_12_LLHC   9.066439   7.259461   9.154211   2.272023   9.253493  10.430306
# col_16_LLHC   4.391630   2.114367   4.793896   3.494416   7.269220   6.893241
#
#              AT3G54500  AT5G62360  AT3G12320  AT2G46830  ...  AT1G15950  \
# Scan REF                                                 ...
# col_0_LLHC    8.275752   3.569248   6.244697  10.145435  ...   9.880410
# col_4_LLHC   10.539178   2.584963   9.865347   9.883651  ...   9.252334
# col_8_LLHC    9.597755   7.328406   7.724241   6.984475  ...   8.761884
# col_12_LLHC   5.125568   9.788098   3.321928   3.061776  ...   7.961102
# ...

# %%
PyWGCNA_1304.preprocess()
# Out:
# Pre-processing...
# 	Detecting genes and samples with too many missing values...
# 	Done pre-processing..

# %%
PyWGCNA_1304.findModules()
# Out:
# Run WGCNA...
# pickSoftThreshold: calculating connectivity for given powers...
# will use block size  2000
#     Power  SFT.R.sq     slope truncated R.sq     mean(k)   median(k)  \
# 0       1  0.929197  2.933004        0.93448  568.732021  601.295009
# 1       2  0.832669   1.39111       0.875975  397.105538  431.495918
# 2       3  0.594683  0.716139       0.658449  301.198873  326.520655
# 3       4  0.311496  0.376306       0.458775  239.110382  256.092305
# 4       5  0.083719  0.151068       0.332081   195.50798  204.947122
# 5       6  0.001712  0.018491       0.298906   163.25228  167.750022
# 6       7  0.078297 -0.119585       0.384513  138.506652  138.372119
# 7       8  0.290254 -0.283939       0.549366  119.002712  116.752039
# 8       9  0.375083 -0.419604       0.623002  103.304426   98.315071
# 9      10  0.447103 -0.539536       0.667453   90.454792   84.184824
# 10     11  0.510586 -0.643489       0.732317   79.790033   71.908214
# ...

# %% [markdown]
# ## Update metadata

# %%
PyWGCNA_1304.updateSampleInfo(path='../data/E-MEXP-1304/eMEXP1304SampleInfo.csv', sep=',')

# Add color to metadata

PyWGCNA_1304.setMetadataColor('Temperature', {'12': 'blue',
                                              '22': 'yellow'})

PyWGCNA_1304.setMetadataColor('Age', {'7days': 'red',
                                          '8days': 'plum',
                                          '9days': 'deeppink'})

PyWGCNA_1304.setMetadataColor('Light', {'Light': 'yellow',
                                             'Dark': 'purple'})

PyWGCNA_1304.setMetadataColor('Tissue', {'Seedling': 'green'})

# %%
PyWGCNA_1304.analyseWGCNA()
# Out:
# Analysing WGCNA...
# Calculating module trait relationship ...
# 	Done..
#
# Adding (signed) eigengene-based connectivity (module membership) ...
# 	Done..
#
# plotting module heatmap eigengene...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4439, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4438 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4439     colors = mcolors.to_rgba_array(c)
#    4440 except (TypeError, ValueError) as err:
#
# File ~/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/matplotlib/colors.py:487, in to_rgba_array(c, alpha)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# ...

# %%
PyWGCNA_1304.saveWGCNA()
# Out:
# Saving WGCNA as E-MEXP-1304-TPM5.p

# %%
PyWGCNA_1304 = PyWGCNA.readWGCNA("E-MEXP-1304-TPM1.p")
# Out:
# Reading E-MEXP-1304-TPM1 WGCNA done!

# %% [markdown]
# # Hub Genes

# %%
PyWGCNA_1304.top_n_hub_genes(moduleName='dimgrey', n=5)
# Out:
# calculating adjacency matrix ...
# 	Done..
#            connectivity dynamicColors moduleColors  moduleLabels
# AT1G67360    690.332038       dimgrey      dimgrey             1
# AT3G23810    690.095997       dimgrey      dimgrey             1
# AT5G57960    689.781890       dimgrey      dimgrey             1
# AT3G55120    689.713069       dimgrey      dimgrey             1
# AT5G17050    689.417232       dimgrey      dimgrey             1

# %%
PyWGCNA_1304.top_n_hub_genes(moduleName='darkgrey', n=5)
# Out:
# calculating adjacency matrix ...
# 	Done..
#            connectivity dynamicColors moduleColors  moduleLabels
# AT2G46550    421.938489      darkgrey     darkgrey             0
# AT1G11260    421.938442      darkgrey     darkgrey             0
# AT2G03310    421.422920      darkgrey     darkgrey             0
# AT4G03510    419.638961      darkgrey     darkgrey             0
# AT5G24490    417.900969      darkgrey     darkgrey             0

# %%
PyWGCNA_1304.top_n_hub_genes(moduleName='lightgrey', n=5)
# Out:
# calculating adjacency matrix ...
# 	Done..
#            connectivity dynamicColors moduleColors  moduleLabels
# AT2G18360    159.528602     lightgrey    lightgrey             2
# AT5G63560    159.434574     lightgrey    lightgrey             2
# AT3G44540    158.876592     lightgrey    lightgrey             2
# AT5G37690    157.310240     lightgrey    lightgrey             2
# AT4G33070    157.132347     lightgrey    lightgrey             2

# %%
modules = PyWGCNA_1304.datExpr.var.moduleColors.unique().tolist()
PyWGCNA_1304.CoexpressionModulePlot(modules=modules, numGenes=100, numConnections=1000, minTOM=0, file_name="all")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 modules = PyWGCNA_1304.datExpr.var.moduleColors.unique().tolist()
# ----> 2 PyWGCNA_1304.CoexpressionModulePlot(modules=modules, numGenes=100, numConnections=1000, minTOM=0, file_name="all")
#
# File ~/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/PyWGCNA/wgcna.py:3391, in WGCNA.CoexpressionModulePlot(self, modules, numGenes, numConnections, minTOM, filters, file_name)
#    3389     else:
#    3390         file_name = "network"
# -> 3391 net.show(f"{self.outputPath}/figures/network/{file_name}.html")
#
# File ~/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/pyvis/network.py:551, in Network.show(self, name, local)
#     549     return self.write_html(name, local, notebook=True)
#     550 else:
# --> 551     self.write_html(name, local)
#
# ...

# %% [markdown]
# # Functional Enrichment Analysis

# %%
geneList = PyWGCNA.getGeneList(dataset='athaliana_eg_gene',
                               attributes=['ensembl_gene_id',
                                           'external_gene_name',
                                           'gene_biotype'],
                               maps=['gene_id', 'gene_name', 'gene_biotype'])

# %%
PyWGCNA_1304.updateGeneInfo(geneList)

# %%
PyWGCNA_1304.figureType = "png"
gene_set_library = ["GO_Biological_Process_2021", "GO_Cellular_Component_2021", "GO_Molecular_Function_2021"]
PyWGCNA_1304.functional_enrichment_analysis(type="GO",
                                             moduleName="dimgrey",
                                             sets=gene_set_library,
                                             p_value=0.10,
                                             file_name="GO_Dimgrey_2021")
# Out:
# No enrich terms when cutoff = 0.1 in module dimgrey

# %%
PyWGCNA_1304.figureType = "png"
gene_set_library = ["KEGG_2019_Mouse"]
PyWGCNA_1304.functional_enrichment_analysis(type="KEGG",
                                             moduleName="dimgrey",
                                             sets=gene_set_library,
                                             p_value=0.05)

# %%
PyWGCNA_1304.figureType = "pdf"
PyWGCNA_1304.functional_enrichment_analysis(type="REACTOME",
                                             moduleName="dimgrey",
                                             p_value=0.05)
# Out:
# REACTOME directory does not exist!
# Creating REACTOME directory!
# Status code returned a value of 404
# 86 out of 1108 genes (identifiers) in the sample were found in Reactome.
# 1233 pathways were hit by at least one of them, which 1 of them have p-value less than 0.05.
# Report was saved /home/ribei027/wgcna/analysis_notebooksfigures/REACTOME/dimgrey.pdf!
# For more information please visit https://reactome.org/PathwayBrowser/#/DTAB=AN&ANALYSIS=MjAyMzA3MjcxMjAzMDFfMzc2Mw%3D%3D

# %% [markdown]
# ## Module Comparison

# %%
PyWGCNA_1304_TPM0 = PyWGCNA.readWGCNA("E-MEXP-1304-TPM0.p")
PyWGCNA_1304_TPM1 = PyWGCNA.readWGCNA("E-MEXP-1304-TPM1.p")
PyWGCNA_1304_TPM2 = PyWGCNA.readWGCNA("E-MEXP-1304-TPM2.p")
PyWGCNA_1304_TPM5 = PyWGCNA.readWGCNA("E-MEXP-1304-TPM5.p")
PyWGCNA_1304_TPM6 = PyWGCNA.readWGCNA("E-MEXP-1304-TPM6.p")
# Out:
# Reading E-MEXP-1304-TPM0 WGCNA done!
# Reading E-MEXP-1304-TPM1 WGCNA done!
# Reading E-MEXP-1304-TPM2 WGCNA done!
# Reading E-MEXP-1304-TPM5 WGCNA done!
# Reading E-MEXP-1304-TPM6 WGCNA done!

# %%
comparison = PyWGCNA.compareNetworks(PyWGCNAs=[PyWGCNA_1304_TPM0,
                                                PyWGCNA_1304_TPM1,
                                                PyWGCNA_1304_TPM2,
                                                PyWGCNA_1304_TPM5,
                                                PyWGCNA_1304_TPM6])

# %%
comparison.jaccard_similarity
# Out:
#                             E-MEXP-1304-TPM0:dimgrey  \
# E-MEXP-1304-TPM0:dimgrey                    1.000000
# E-MEXP-1304-TPM0:darkgrey                   0.000000
# E-MEXP-1304-TPM0:lightgrey                  0.000000
# E-MEXP-1304-TPM1:dimgrey                    1.000000
# E-MEXP-1304-TPM1:darkgrey                   0.000000
# E-MEXP-1304-TPM1:lightgrey                  0.000000
# E-MEXP-1304-TPM2:dimgrey                    1.000000
# E-MEXP-1304-TPM2:darkgrey                   0.000000
# E-MEXP-1304-TPM2:lightgrey                  0.000000
# E-MEXP-1304-TPM5:dimgrey                    0.810330
# E-MEXP-1304-TPM5:darkgrey                   0.031863
# E-MEXP-1304-TPM5:lightgrey                  0.007519
# E-MEXP-1304-TPM5:silver                     0.030516
# E-MEXP-1304-TPM6:dimgrey                    0.703824
# E-MEXP-1304-TPM6:darkgrey                   0.033832
# E-MEXP-1304-TPM6:gainsboro                  0.009202
#
#                             E-MEXP-1304-TPM0:darkgrey  \
# ...

# %%
comparison.fraction
# Out:
#                             E-MEXP-1304-TPM0:dimgrey  \
# E-MEXP-1304-TPM0:dimgrey                    1.000000
# E-MEXP-1304-TPM0:darkgrey                   0.000000
# E-MEXP-1304-TPM0:lightgrey                  0.000000
# E-MEXP-1304-TPM1:dimgrey                  100.000000
# E-MEXP-1304-TPM1:darkgrey                   0.000000
# E-MEXP-1304-TPM1:lightgrey                  0.000000
# E-MEXP-1304-TPM2:dimgrey                  100.000000
# E-MEXP-1304-TPM2:darkgrey                   0.000000
# E-MEXP-1304-TPM2:lightgrey                  0.000000
# E-MEXP-1304-TPM5:dimgrey                   86.371841
# E-MEXP-1304-TPM5:darkgrey                   4.693141
# E-MEXP-1304-TPM5:lightgrey                  0.812274
# E-MEXP-1304-TPM5:silver                     3.519856
# E-MEXP-1304-TPM6:dimgrey                   78.068592
# E-MEXP-1304-TPM6:darkgrey                   4.693141
# E-MEXP-1304-TPM6:gainsboro                  1.083032
#
#                             E-MEXP-1304-TPM0:darkgrey  \
# ...
