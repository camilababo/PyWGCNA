# %% [markdown]
# # PyWGCNA with E-MEXP-1304

# %%
import PyWGCNA

# %% [markdown]
# ## Setting up the data and preprocessing
# Starting with the transposed dataset related to the top 2000 most deviating genes calculated by MAD

# %%
geneExp = "../data/E-MEXP-1304-Complete/eMEXP1304AllConditions-prepocessed-filtered-transposed.csv"
PyWGCNA_1304_All = PyWGCNA.WGCNA(name='E-MEXP-1304-All',
                                  species='arabidopsis thaliana',
                                  geneExpPath=geneExp,
                                  outputPath='/home/ribei027/wgcna/analysis_notebooks',
                                  save=True)
PyWGCNA_1304_All.geneExpr.to_df().head(5)
# Out:
# Saving data to be True, checking requirements ...
#                 AT2G42530  AT3G21720  AT5G04120  AT1G01060  AT2G47780  \
# col_0_DD_DDHC    2.613532  12.964978  10.836327   8.278403  11.463785
# col_4_DD_DDHC    3.028569  12.857577  10.931661   7.700370  11.382710
# col_8_DD_DDHC    2.771886  13.006824  11.772187   2.364572  11.477596
# col_12_DD_DDHC   3.263034  13.122721  11.925328   1.992768  11.339633
# col_16_DD_DDHC   2.673556  13.283826  12.184993   2.684819  11.636498
#
#                 AT2G42540  AT5G54190  AT3G02380  AT2G25510  AT5G62360  ...  \
# col_0_DD_DDHC    4.139961  11.595183   5.916715   3.116032   2.244887  ...
# col_4_DD_DDHC    3.023255  12.145741   4.495695   2.550901   1.906891  ...
# col_8_DD_DDHC    2.711495  12.393742   2.893362   2.503349   1.996389  ...
# col_12_DD_DDHC   2.456806  11.655857   2.761285   2.555816   2.207893  ...
# col_16_DD_DDHC   2.987321  12.209173   3.168321   2.641546   2.319040  ...
#
#                 ATCG00770  AT1G26665  AT3G15110  AT4G29140  AT3G13062  \
# col_0_DD_DDHC    3.232661   7.924694   5.093391   7.018923   4.609400
# col_4_DD_DDHC    6.187451   7.916238   6.205549   5.702381   4.800123
# col_8_DD_DDHC    4.425594   9.027243   6.229588   5.786074   5.636045
# col_12_DD_DDHC   6.089371   9.199623   5.572890   6.100767   5.672991
# col_16_DD_DDHC   5.173927   9.451891   6.716031   5.747656   6.412273
#
#                 AT3G46700  AT2G15880  AT4G34220  AT1G25560  AT3G10280
# col_0_DD_DDHC    3.883621   3.030336   6.142005   7.146696   2.414136
# col_4_DD_DDHC    5.022812   2.427606   5.533875   8.169825   2.411426
# col_8_DD_DDHC    4.196922   2.592158   5.311067   8.587853   3.301588
# col_12_DD_DDHC   5.182295   2.761285   5.633141   8.970278   2.472488
# col_16_DD_DDHC   4.090007   3.010780   6.289097   9.478446   3.114367
#
# [5 rows x 2000 columns]

# %%
PyWGCNA_1304_All.preprocess()
# Out:
# Pre-processing...
# 	Detecting genes and samples with too many missing values...
# 	Done pre-processing..

# %%
PyWGCNA_1304_All.findModules()
# Out:
# Run WGCNA...
# pickSoftThreshold: calculating connectivity for given powers...
# will use block size  2000
#     Power  SFT.R.sq     slope truncated R.sq     mean(k)   median(k)  \
# 0       1  0.826142   1.74339       0.874847  600.613171  668.211113
# 1       2  0.591829  0.645294       0.814622  431.903184  495.040799
# 2       3  0.205099  0.237602       0.556125  333.518742  381.906683
# 3       4  0.000213  0.006574       0.058115  267.969996  301.879152
# 4       5  0.094399 -0.140576      -0.031661  220.962366  242.695493
# 5       6  0.232873 -0.257433       0.050261   185.62242  197.388145
# 6       7  0.366172 -0.357327       0.185092  158.160684  161.500066
# 7       8  0.433574 -0.435265       0.290969  136.289182  133.566228
# 8       9   0.49811 -0.507579       0.397475  118.533656  110.795275
# 9      10  0.567528 -0.559698       0.509228  103.896506   93.464029
# 10     11  0.597415 -0.612378       0.572684   91.676409   78.504463
# 11     13  0.683808 -0.682715        0.70907   72.584456   56.433085
# 12     15    0.7077 -0.756547       0.751914   58.534179   41.061583
# 13     17  0.750624 -0.809751       0.817031   47.915107   29.921506
# 14     19  0.773566 -0.873952       0.843595   39.716335   22.186662
#
#         max(k)
# 0   758.702237
# 1   643.498008
# 2    564.45402
# 3    504.33091
# 4   456.009251
# 5   415.805121
# 6   381.556552
# 7   351.881857
# 8   325.840531
# 9   302.760333
# 10  282.141811
# 11  246.840653
# 12  217.730903
# 13  193.354949
# 14  173.387618
# No power detected to have scale free network!
# Found the best given power which is 1.
# calculating adjacency matrix ...
# 	Done..
#
# calculating TOM similarity matrix ...
# 	Done..
#
# Going through the merge tree...
# ..cutHeight not given, setting it to 0.968  ===>  99% of the (truncated) height range in dendro.
# 	Done..
#
# Calculating 2 module eigengenes in given set...
# 	Done..
#
# mergeCloseModules: Merging modules whose distance is less than 0.2
# fixDataStructure: data is not a Dictionary: converting it into one.
# multiSetMEs: Calculating module MEs.
#   Working on set 1 ...
# Calculating 2 module eigengenes in given set...
# 	Done..
#
#   Calculating new MEs...
# multiSetMEs: Calculating module MEs.
#   Working on set 1 ...
# Calculating 2 module eigengenes in given set...
# 	Done..
#
# Calculating 2 module eigengenes in given set...
# 	Done..
#
# fixDataStructure: data is not a Dictionary: converting it into one.
# orderMEs: order not given, calculating using given set 0
# 	Done running WGCNA..

# %% [markdown]
# ## Update metadata

# %%
PyWGCNA_1304_All.updateSampleInfo(path='../data/E-MEXP-1304-Complete/eMEXP1304AllConditionsSampleInfo.csv', sep=',')

# Add color to metadata

PyWGCNA_1304_All.setMetadataColor('Temperature', {'12': 'blue',
                                              '22': 'yellow'})

PyWGCNA_1304_All.setMetadataColor('Age', {'7days': 'red',
                                          '8days': 'plum',
                                          '9days': 'deppink',})

PyWGCNA_1304_All.setMetadataColor('Light', {'Light': 'yellow',
                                             'Dark': 'purple'})

# %%
PyWGCNA_1304_All.analyseWGCNA()
# Out:
# Analysing WGCNA...
# Calculating module trait relationship ...
# 	Done..
#
# Adding (signed) eigengene-based connectivity (module membership) ...
# 	Done..
#
# plotting module heatmap eigengene...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 PyWGCNA_1304_All.analyseWGCNA()
#
# File ~/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/PyWGCNA/wgcna.py:441, in WGCNA.analyseWGCNA(self, order, geneList, show)
#     439     print(f"{OKCYAN}plotting module heatmap eigengene...{ENDC}")
#     440     for module in modules:
# --> 441         self.plotModuleEigenGene(module, metadata, show=False)
#     442     print("\tDone..\n")
#     444 if self.save:
#
# File ~/miniconda3/envs/pywgcna3/lib/python3.9/site-packages/PyWGCNA/wgcna.py:2838, in WGCNA.plotModuleEigenGene(self, moduleName, metadata, show)
#    2836 height_ratios = []
#    2837 for m in metadata:
# -> 2838     height_ratios.append(len(list(self.metadataColors[m].keys())))
#    2839 height_ratios.reverse()
#    2841 modules = np.unique(self.datExpr.var['moduleColors']).tolist()
#
# KeyError: 'Tissue'

# %% [markdown]
# # Functional Enrichment Analysis

# %%
PyWGCNA_1304_All.saveWGCNA()
# Out:
# Saving WGCNA as E-MEXP-1304-All.p

# %%
PyWGCNA_1304_All = PyWGCNA.readWGCNA("E-MEXP-1304.p")
# Out:
# Reading E-MEXP-1304 WGCNA done!

# %%
geneList = PyWGCNA.getGeneList(dataset='athaliana_eg_gene',
                               attributes=['ensembl_gene_id',
                                           'external_gene_name',
                                           'gene_biotype'],
                               maps=['gene_id', 'gene_name', 'gene_biotype'])

# %%
PyWGCNA_1304_All.updateGeneInfo(geneList)

# %%
PyWGCNA_1304_All.figureType = "png"
gene_set_library = ["GO_Biological_Process_2021", "GO_Cellular_Component_2021", "GO_Molecular_Function_2021"]
PyWGCNA_1304_All.functional_enrichment_analysis(type="GO",
                                             moduleName="dimgrey",
                                             sets=gene_set_library,
                                             p_value=0.05,
                                             file_name="GO_Dimgrey_2021")
# Out:
# No enrich terms when cutoff = 0.05 in module dimgrey
